# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import r2_score, accuracy_score
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print("dataset shape:",df.shape)
print("sample data:\n",df.head(2))
# Out:
# dataset shape: (1460, 81)
# sample data:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
#selecting relevant features
features= ['FullBath','HalfBath','BedroomAbvGr','Fireplaces']
target= 'SalePrice'
df=df[features+[target]]

# %%
#removing outliers
imputer = SimpleImputer(strategy='median')
df[features]=imputer.fit_transform(df[features])

# Remove outliers (optional)
df = df[df['SalePrice'] < df['SalePrice'].quantile(0.95)]

# %%
#removing outliers
df = df[df['SalePrice'] < df['SalePrice'].quantile(0.95)]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, df[target], test_size=0.2, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4050105620.py in <cell line: 0>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X_scaled, df[target], test_size=0.2, random_state=2)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2846         raise ValueError("At least one array required as input")
#    2847
# -> 2848     arrays = indexable(*arrays)
# ...

# %%
#prediction of pricing
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred_price = lr_model.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred_price)

# %%
#classification
def categorize(price):
    if price < 170000:
        return 'Low'
    elif price < 950000:
        return 'Medium'
    else:
        return 'High'

df['PriceCategory'] = df['SalePrice'].apply(categorize)

# %%
#classification of dataset
X_cls = X_scaled
y_cls = df['PriceCategory']

# %%
#Applying Random forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_cls, y_train_cls)
rf_pred = rf_model.predict(X_test_cls)
rf_acc = accuracy_score(y_test_cls, rf_pred)
print(f"\nRandom Forest Accuracy: {rf_acc:.3f}")
# Out:
# Random Forest Accuracy: 0.788

# %%
#prediction of area, rooms etc
example = np.array([[1500, 3, 2, 1, 7000]])
example_scaled = scaler.transform(example)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#prediction of price
pred_price = lr_model.predict(example_scaled)[0]

# %%
#prediction of category
pred_cat_rf = le.inverse_transform(rf_model.predict(example_scaled))[0]

print(f"\nExample House:")
print(f"Predicted Price: ${pred_price:,.0f}")
print(f"Predicted Category (RF): {pred_cat_rf}")
# Out:
# Example House:
# Predicted Price: $156,119
# Predicted Category (RF): Low

# %%
#Regression model predicts the exact house price and Random Forest classify houses into Low, Medium, or High values Scaling keeps features balanced and outlier removal improves accuracy, the R² score shows how well the price model fits the data, and accuracy tells how well the classification model is correct.
